# %% [markdown]
# # 🤖 Camunda Migration Assistant - Notebook Interativo
#
# Este notebook demonstra como usar o assistente de migração Camunda 7 → 8 em um ambiente Jupyter.
#
# ## 📋 Pré-requisitos
#
# 1. Instale as dependências: `pip install -r requirements.txt`
# 2. Configure sua `GOOGLE_API_KEY`

# %% [markdown]
# ## 1️⃣ Configuração Inicial

# %%
import os
from pathlib import Path

# Configure sua API Key aqui (ou use variável de ambiente)
# IMPORTANTE: Não commite este notebook com sua API key!
GOOGLE_API_KEY = os.environ.get('GOOGLE_API_KEY', '')  # ou cole sua chave aqui temporariamente

if not GOOGLE_API_KEY:
    print("⚠️  Configure GOOGLE_API_KEY antes de continuar!")
    print("   Obtenha em: https://aistudio.google.com/app/apikey")
else:
    print("✅ API Key configurada!")

# %% [markdown]
# ## 2️⃣ Importar e Inicializar o Chatbot

# %%
from camunda_migration_chatbot import CamundaMigrationChatbot

# Inicializa o chatbot
chatbot = CamundaMigrationChatbot(api_key=GOOGLE_API_KEY)

print("✅ Chatbot inicializado!")

# %% [markdown]
# ## 3️⃣ Setup: Upload da Documentação
#
# ⚠️ **ATENÇÃO**: Este passo pode levar alguns minutos na primeira execução, pois faz upload de todos os PDFs.

# %%
# Setup - necessário apenas uma vez
# Descomente a linha abaixo para executar
# chatbot.setup()

print("⚠️  Descomente a linha acima e execute para fazer o setup inicial")

# %% [markdown]
# ## 4️⃣ Fazer Perguntas
#
# Agora você pode fazer perguntas sobre a migração!

# %%
# Exemplo: Pergunta sobre diferenças conceituais
response = chatbot.ask(
    "Quais são as principais diferenças arquiteturais entre Camunda 7 e Camunda 8?"
)

# %% [markdown]
# ## 5️⃣ Sua Própria Pergunta
#
# Use a célula abaixo para fazer suas próprias perguntas:

# %%
# Coloque sua pergunta aqui
minha_pergunta = "Digite sua pergunta aqui"

response = chatbot.ask(minha_pergunta)
